# %% [markdown]
# # Rent price in NYC

# %% [markdown]
# ## 1. Import Modules:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2. Download and clean the data

# %% [markdown]
# ### 2.1. Read the dataset into pandas

# %%
df_rent = pd.read_csv('medianAskingRent_All.csv')

df_rent.head()
# Out:
#               areaName    Borough   areaType  2010-01  2010-02  2010-03  \
# 0         All Downtown  Manhattan  submarket   3200.0   3200.0   3025.0
# 1          All Midtown  Manhattan  submarket   2875.0   2800.0   2800.0
# 2  All Upper East Side  Manhattan  submarket   2460.0   2450.0   2400.0
# 3  All Upper Manhattan  Manhattan  submarket   1836.0   1800.0   1795.0
# 4  All Upper West Side  Manhattan  submarket   2895.0   2800.0   2750.0
#
#    2010-04  2010-05  2010-06  2010-07  ...  2020-01  2020-02  2020-03  \
# 0   3100.0   3100.0   3200.0   3195.0  ...   4000.0   3999.0   3995.0
# 1   2850.0   2895.0   2950.0   3000.0  ...   3700.0   3700.0   3695.0
# 2   2500.0   2550.0   2550.0   2595.0  ...   3295.0   3250.0   3250.0
# 3   1800.0   1823.0   1850.0   1875.0  ...   2383.0   2400.0   2450.0
# 4   2800.0   2800.0   2795.0   2800.0  ...   3650.0   3589.0   3509.0
#
#    2020-04  2020-05  2020-06  2020-07  2020-08  2020-09  2020-10
# ...

# %% [markdown]
# ### 2.2. Calculate average rent price for each area

# %%
df_rent['Average rent price'] = df_rent.mean(axis=1)
df_rent
# Out:
#                 areaName    Borough      areaType  2010-01  2010-02  2010-03  \
# 0           All Downtown  Manhattan     submarket   3200.0   3200.0   3025.0
# 1            All Midtown  Manhattan     submarket   2875.0   2800.0   2800.0
# 2    All Upper East Side  Manhattan     submarket   2460.0   2450.0   2400.0
# 3    All Upper Manhattan  Manhattan     submarket   1836.0   1800.0   1795.0
# 4    All Upper West Side  Manhattan     submarket   2895.0   2800.0   2750.0
# ..                   ...        ...           ...      ...      ...      ...
# 193      Windsor Terrace   Brooklyn  neighborhood   1600.0   1650.0   1650.0
# 194            Woodhaven     Queens  neighborhood      NaN      NaN      NaN
# 195             Woodlawn      Bronx  neighborhood      NaN      NaN      NaN
# 196             Woodside     Queens  neighborhood   1813.0      NaN   1398.0
# 197            Woodstock      Bronx  neighborhood      NaN      NaN      NaN
#
# ...

# %%
df_rent['Average rent price'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### 2.3. Clean up and arrange the data

# %%
#drop whole row with "submarket" in 'areaType' column
df_rent.drop(df_rent.index[df_rent['areaType'] == 'submarket'], inplace = True)

#reset index because we dropped rows
df_rent.reset_index(drop=True, inplace=True)

# for sake of consistency, let's also make all column labels of type string
df_rent.columns = list(map(str, df_rent.columns))

df_rent
# Out:
#               areaName    Borough      areaType  2010-01  2010-02  2010-03  \
# 0              Astoria     Queens  neighborhood   1600.0   1650.0   1620.0
# 1           Auburndale     Queens  neighborhood      NaN      NaN      NaN
# 2           Bath Beach   Brooklyn  neighborhood      NaN      NaN      NaN
# 3    Battery Park City  Manhattan  neighborhood   3495.0   3346.0   3268.0
# 4            Bay Ridge   Brooklyn  neighborhood   1350.0   1388.0   1350.0
# ..                 ...        ...           ...      ...      ...      ...
# 178    Windsor Terrace   Brooklyn  neighborhood   1600.0   1650.0   1650.0
# 179          Woodhaven     Queens  neighborhood      NaN      NaN      NaN
# 180           Woodlawn      Bronx  neighborhood      NaN      NaN      NaN
# 181           Woodside     Queens  neighborhood   1813.0      NaN   1398.0
# 182          Woodstock      Bronx  neighborhood      NaN      NaN      NaN
#
# ...

# %%
#set the areaName as index
df_rent.set_index('areaName', inplace=True)

#sort data descending based on mean rent price
df_rent.sort_values(['Average rent price'], ascending=False, axis=0, inplace=True)
df_rent
# Out:
#                        Borough      areaType  2010-01  2010-02  2010-03  \
# areaName
# Central Park South   Manhattan  neighborhood   6000.0   6000.0   5950.0
# Tribeca              Manhattan  neighborhood   6625.0   6773.0   6500.0
# Soho                 Manhattan  neighborhood   5200.0   5288.0   5275.0
# Flatiron             Manhattan  neighborhood   3895.0   3750.0   3550.0
# DUMBO                 Brooklyn  neighborhood   3275.0   3200.0   2800.0
# ...                        ...           ...      ...      ...      ...
# South Jamaica           Queens  neighborhood      NaN      NaN      NaN
# South Ozone Park        Queens  neighborhood      NaN      NaN      NaN
# South Richmond Hill     Queens  neighborhood      NaN      NaN      NaN
# Springfield Gardens     Queens  neighborhood      NaN      NaN      NaN
# Utopia                  Queens  neighborhood      NaN      NaN      NaN
#
#                      2010-04  2010-05  2010-06  2010-07  2010-08  ...  \
# ...

# %%
#drop whole row with Nan in 'mean' column
df_rent.dropna(subset=["Average rent price"], axis=0, inplace=True)
df_rent
# Out:
#                        Borough      areaType  2010-01  2010-02  2010-03  \
# areaName
# Central Park South   Manhattan  neighborhood   6000.0   6000.0   5950.0
# Tribeca              Manhattan  neighborhood   6625.0   6773.0   6500.0
# Soho                 Manhattan  neighborhood   5200.0   5288.0   5275.0
# Flatiron             Manhattan  neighborhood   3895.0   3750.0   3550.0
# DUMBO                 Brooklyn  neighborhood   3275.0   3200.0   2800.0
# ...                        ...           ...      ...      ...      ...
# Westchester Village      Bronx  neighborhood      NaN      NaN      NaN
# Bedford Park             Bronx  neighborhood      NaN      NaN      NaN
# Van Nest                 Bronx  neighborhood      NaN      NaN      NaN
# Parkchester              Bronx  neighborhood      NaN      NaN      NaN
# University Heights       Bronx  neighborhood   1100.0   1100.0      NaN
#
#                      2010-04  2010-05  2010-06  2010-07  2010-08  ...  \
# ...

# %% [markdown]
# ## 3. Visualise the data

# %%
# use the inline backend to generate the plots within the browser
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__)
# Out:
# Matplotlib version:  3.3.3

# %% [markdown]
# ### 3.1. Plot average rent price in neighborhoods in a barchart

# %%
#plot all areas in one barchart
df_rent['Average rent price'].plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Average rent price')
plt.title('Average rent price in New York City neighbourhoods')

# annotate value labels to each area
for index, value in enumerate(df_rent['Average rent price']): 
    label = format(float(value)) 


plt.show()

# %%
# get top 80 areas
df_top80 = df_rent['Average rent price'].head(80)
df_top80
# Out:
# areaName
# Central Park South     6944.169231
# Tribeca                6657.946154
# Soho                   4979.400000
# Flatiron               4463.669231
# DUMBO                  4213.146154
#                           ...
# Maspeth                2010.954023
# Forest Hills           2008.553846
# Prospect Park South    2007.030612
# Bellerose              2003.571429
# Auburndale             1999.731343
# Name: Average rent price, Length: 80, dtype: float64

# %%
#plot top 80 areas
df_top80.plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Average rent price')
plt.title('Average rent price in top 80 New York City neighbourhoods')

# annotate value labels to each area
for index, value in enumerate(df_top80): 
    label = format(float(value))


plt.show()

# %%
# get bottom 80 areas
df_bottom80 = df_rent['Average rent price'].tail(80)
df_bottom80
# Out:
# areaName
# Bellerose              2003.571429
# Auburndale             1999.731343
# Throgs Neck            1992.581395
# Marine Park            1989.968750
# Washington Heights     1980.230769
#                           ...
# Westchester Village    1500.000000
# Bedford Park           1475.024096
# Van Nest               1472.307692
# Parkchester            1447.819444
# University Heights     1442.577982
# Name: Average rent price, Length: 80, dtype: float64

# %%
#plot bottom 80 areas
df_bottom80.plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Average rent price')
plt.title('Average rent price in bottom 80 New York City neighbourhoods')

# annotate value labels to each area
for index, value in enumerate(df_bottom80): 
    label = format(float(value))


plt.show()

# %% [markdown]
# ### 3.2. Plot average rent price in boroughs in a barchart

# %%
#group data by boroguh
df_group_borough = df_rent[['Borough','Average rent price']]
df_group_borough = df_group_borough.groupby(['Borough'],as_index=False).mean()
df_group_borough.set_index('Borough', inplace=True)
df_group_borough.sort_values(['Average rent price'], ascending=False, axis=0, inplace=True)
df_group_borough
# Out:
#                Average rent price
# Borough
# Manhattan             3414.966562
# Brooklyn              2316.537023
# Queens                1998.499714
# Staten Island         1815.425743
# Bronx                 1700.295597

# %%
#plot average rent prices by borough
df_group_borough.plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Average rent price')
plt.title('Average rent price in New York City boroughs')

for index, value in enumerate(df_group_borough): 
    label = format(str(value))
    
plt.show()
